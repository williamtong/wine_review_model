# %%
import pandas as pd
import numpy as np
import re

import collections

import os

from sklearn.model_selection import  train_test_split
from sklearn.pipeline import Pipeline

import pickle

import gzip

# %%
os.chdir('../')
from functions.featurization import (saint_words,
                                    stop_words,
                                    location_info_features,
                                    Preprocess_Data,
                                    variety_tokenizer,
                                    individual_text_processing,
                                    text_tokenizer,
                                    Create_Simple_Onehot, 
                                    Create_Multigrams,
                                    Merge_Similar_Columns,
                                    Normalize_Points,
)
# Out:
# [nltk_data] Downloading package punkt to /Users/willtong/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_json("data/mod_winemag-data-130k-v2.json")
df = df.replace("[+]", "Plus") 
df = df.replace("[", "") 
df = df.replace("]", "") 
# df[df["designation"].fillna('xxxxx').apply(lambda text: '+' in text or '[' in text or ']' in text)]["designation"]

# %%
X_train, X_holdout, y_train, y_holdout = train_test_split(df.drop(["price"], axis = 1), 
                                                          df["price"], test_size = 0.1, train_size=0.9, 
                                                          random_state = 5)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, train_size=0.9, random_state = 5)

# %%
winery_threshold_frac = 0.0002
winery_threshold_count = int(winery_threshold_frac*X_train.shape[0]+0.5)
designation_threshold_frac = 0.00010
designation_threshold_count = int(winery_threshold_frac*X_train.shape[0]+0.5)
title_threshold_frac = 0.001
title_threshold_count = int(title_threshold_frac*X_train.shape[0]+0.5)
variety_threshold_frac = 0.001
variety_threshold_count = int(variety_threshold_frac*X_train.shape[0]+0.5)
taster_threshold_frac = 0.00001
taster_threshold_count = int(taster_threshold_frac*X_train.shape[0]+0.5)

featurize_pipeline = Pipeline(
    steps = [
             ('preprocess_data', Preprocess_Data(columns_to_drop = ['taster-twitter-handle', 'description'],
                                                 columns_to_impute_unknown = ['taster-name',
                                                 ])),
             ('norm_points', Normalize_Points(point_feature = 'points', groupby_feature = 'taster-name')),
        
             ("title_tokenizer", Create_Multigrams(tokenizer=text_tokenizer, 
                                                   feature = 'title', 
                                                   threshold_frac = title_threshold_frac)),
             ("variety_tokenizer", Create_Multigrams(tokenizer=variety_tokenizer, 
                                                     feature = 'variety',
                                                     threshold_frac = variety_threshold_frac
                                                    )), 

             ('winery_name_onehot', Create_Simple_Onehot(feature ="winery", 
                                                    threshold_frac = winery_threshold_frac)),
             ('designation_onehot', Create_Simple_Onehot(feature ="designation", 
                                                         threshold_frac = designation_threshold_frac)),
             ('region-1_onehot', Create_Simple_Onehot(feature ="region-1", 
                                                         threshold_frac = designation_threshold_frac)),
        
             ('region-2_onehot', Create_Simple_Onehot(feature ="region-2", 
                                                         threshold_frac = designation_threshold_frac)),
        
             ('province_onehot', Create_Simple_Onehot(feature ="province", 
                                                         threshold_frac = designation_threshold_frac)),
        
             ('country_onehot', Create_Simple_Onehot(feature ="country", 
                                                         threshold_frac = designation_threshold_frac)),
             ('taster-name_onehot', Create_Simple_Onehot(feature ="taster-name", 
                                                         threshold_frac = designation_threshold_frac)),
             ('merge_similar_columns', Merge_Similar_Columns()),
            ]
)
featurize_pipeline.fit(X_train)
# Out:
# Fitting normalized_points for point_features = points, groupby taster-name
# Calculating normalized point for each taster based on training data
# Creating multigrams for feature = title
# feature tokenized = title, output dataframe shape = (97989, 701)
# Creating multigrams for feature = variety
# feature tokenized = variety, output dataframe shape = (97989, 788)
# Creating simple onehot for feature = winery
# feature onehotted = winery, output dataframe shape = (97989, 1907)
# Creating simple onehot for feature = designation
# feature onehotted = designation, output dataframe shape = (97989, 2427)
# Creating simple onehot for feature = region-1
# feature onehotted = region-1, output dataframe shape = (97989, 3011)
# Creating simple onehot for feature = region-2
# feature onehotted = region-2, output dataframe shape = (97989, 3026)
# Creating simple onehot for feature = province
# feature onehotted = province, output dataframe shape = (97989, 3235)
# Creating simple onehot for feature = country
# feature onehotted = country, output dataframe shape = (97989, 3266)
# Creating simple onehot for feature = taster-name
# feature onehotted = taster-name, output dataframe shape = (97989, 3283)
# Duplicated columns to be merged are {'garnacha', 'red', 'nero', 'verdot', 'new mexico', 'muscat', 'veltliner', 'western australia', 'sec', 'oregon', 'alta', 'chianti', 'blaufränkisch', 'crianza', 'gewürztraminer', 'petite', 'missouri', 'portugal', 'made with organic grapes', 'riesling', 'bianchi', 'victoria', 'virginia', 'organic', 'noir', 'long island', 'signature', 'barolo', 'unfiltered', 'spätlese', 'southern oregon', 'argentina', 'rosso', 'selección', 'classic', 'tinto', 'lebanon', 'syrah', 'port', 'friulano', 'estate', 'toro', 'vintage', 'branco', 'veneto', 'brut', 'unoaked', 'chenin', 'chalk hill', 'roble', 'new zealand', 'austria', 'viognier', 'gran', 'montepulciano', 'reserva', 'england', 'testarossa', 'premium', 'sangiovese', 'ukraine', 'wellington', 'montes', 'piedmont', 'trocken', 'tannat', 'italy', 'chile', 'finger lakes', 'semillon', 'willamette valley', 'sirah', 'tempranillo', 'rosato', 'franc', 'bella', 'north coast', 'hall', 'petit', 'zweigelt', 'bourgogne', 'moldova', 'mencía', 'colorado', 'nebbiolo', 'verdejo', 'tasmania', 'beaujolais', 'domaine', 'touriga', 'alsace', 'rouge', 'loire valley', 'tradition', 'sparkling', 'viura', 'sonoma', 'zinfandel', 'grüner', 'gris', 'sauvignon', 'rosado', 'texas', 'prestige', 'select', 'barbera', 'mourvèdre', 'napa-sonoma', 'rosé', 'spain', 'central valley', 'valpolicella', 'turkey', 'aglianico', 'nacional', 'vermentino', 'blanc', 'terroir', 'georgia', 'colheita', 'heritage', 'auslese', 'moscato', 'siduri', 'prosecco', 'germany', 'greece', 'south coast', 'australia', 'uruguay', 'monastrell', 'cabernet', 'sweet', 'napa', 'romania', 'torrontés', 'white', 'michigan', 'grenache', 'barbaresco', 'riserva', 'ridge', 'carmenère', 'california', 'réserve', 'bianco', 'cuvée', 'selection', 'idaho', 'champagne', 'bordeaux', 'pinotage', 'merlot', 'meritage', 'malbec', 'israel', 'roussanne', 'new york', 'collection', 'primitivo', 'arizona', 'central coast', 'grigio', 'south australia', 'kabinett', 'dry', 'sierra foothills', 'shiraz', 'pinot', 'pennsylvania', 'reserve', 'washington', 'médoc', 'albariño', 'blend', 'chardonnay', 'foxen'}.
# Pipeline(steps=[('preprocess_data',
#                  <functions.featurization.Preprocess_Data object at 0x294027f40>),
#                 ('norm_points',
#                  <functions.featurization.Normalize_Points object at 0x294027f10>),
#                 ('title_tokenizer',
#                  <functions.featurization.Create_Multigrams object at 0x2afc38820>),
#                 ('variety_tokenizer',
#                  <functions.featurization.Create_Multigrams object at 0x2afc38850>),
#                 ('winer...
#                 ('province_onehot',
#                  <functions.featurization.Create_Simple_Onehot object at 0x2afc38a30>),
#                 ('country_onehot',
#                  <functions.featurization.Create_Simple_Onehot object at 0x2afc3a290>),
#                 ('taster-name_onehot',
#                  <functions.featurization.Create_Simple_Onehot object at 0x2afc3a2f0>),
#                 ('merge_similar_columns',
#                  <functions.featurization.Merge_Similar_Columns object at 0x2afc3a350>)])

# %%
X_train_transformed = featurize_pipeline.transform(X_train)
# Out:
# Calculating normalized point for each taster based on training data
# feature tokenized = title, output dataframe shape = (97989, 701)
# feature tokenized = variety, output dataframe shape = (97989, 788)
# feature onehotted = winery, output dataframe shape = (97989, 1907)
# feature onehotted = designation, output dataframe shape = (97989, 2427)
# feature onehotted = region-1, output dataframe shape = (97989, 3011)
# feature onehotted = region-2, output dataframe shape = (97989, 3026)
# feature onehotted = province, output dataframe shape = (97989, 3235)
# feature onehotted = country, output dataframe shape = (97989, 3266)
# feature onehotted = taster-name, output dataframe shape = (97989, 3283)
# Merging the following raw columns: {'garnacha', 'red', 'nero', 'verdot', 'new mexico', 'muscat', 'veltliner', 'western australia', 'sec', 'oregon', 'alta', 'chianti', 'blaufränkisch', 'crianza', 'gewürztraminer', 'petite', 'missouri', 'portugal', 'made with organic grapes', 'riesling', 'bianchi', 'victoria', 'virginia', 'organic', 'noir', 'long island', 'signature', 'barolo', 'unfiltered', 'spätlese', 'southern oregon', 'argentina', 'rosso', 'selección', 'classic', 'tinto', 'lebanon', 'syrah', 'port', 'friulano', 'estate', 'toro', 'vintage', 'branco', 'veneto', 'brut', 'unoaked', 'chenin', 'chalk hill', 'roble', 'new zealand', 'austria', 'viognier', 'gran', 'montepulciano', 'reserva', 'england', 'testarossa', 'premium', 'sangiovese', 'ukraine', 'wellington', 'montes', 'piedmont', 'trocken', 'tannat', 'italy', 'chile', 'finger lakes', 'semillon', 'willamette valley', 'sirah', 'tempranillo', 'rosato', 'franc', 'bella', 'north coast', 'hall', 'petit', 'zweigelt', 'bourgogne', 'moldova', 'mencía', 'colorado', 'nebbiolo', 'verdejo', 'tasmania', 'beaujolais', 'domaine', 'touriga', 'alsace', 'rouge', 'loire valley', 'tradition', 'sparkling', 'viura', 'sonoma', 'zinfandel', 'grüner', 'gris', 'sauvignon', 'rosado', 'texas', 'prestige', 'select', 'barbera', 'mourvèdre', 'napa-sonoma', 'rosé', 'spain', 'central valley', 'valpolicella', 'turkey', 'aglianico', 'nacional', 'vermentino', 'blanc', 'terroir', 'georgia', 'colheita', 'heritage', 'auslese', 'moscato', 'siduri', 'prosecco', 'germany', 'greece', 'south coast', 'australia', 'uruguay', 'monastrell', 'cabernet', 'sweet', 'napa', 'romania', 'torrontés', 'white', 'michigan', 'grenache', 'barbaresco', 'riserva', 'ridge', 'carmenère', 'california', 'réserve', 'bianco', 'cuvée', 'selection', 'idaho', 'champagne', 'bordeaux', 'pinotage', 'merlot', 'meritage', 'malbec', 'israel', 'roussanne', 'new york', 'collection', 'primitivo', 'arizona', 'central coast', 'grigio', 'south australia', 'kabinett', 'dry', 'sierra foothills', 'shiraz', 'pinot', 'pennsylvania', 'reserve', 'washington', 'médoc', 'albariño', 'blend', 'chardonnay', 'foxen'}
# Merging the following columns into one: ['title_garnacha', 'variety_Garnacha', 'designation_Garnacha'].
# Number of columns after merging = 3281
# Merging the following columns into one: ['title_red', 'variety_Red', 'designation_Red'].
# Number of columns after merging = 3279
# Merging the following columns into one: ['title_nero', 'variety_Nero'].
# Number of columns after merging = 3278
# Merging the following columns into one: ['title_verdot', 'variety_Verdot'].
# Number of columns after merging = 3277
# Merging the following columns into one: ['region-1_New Mexico', 'province_New Mexico'].
# Number of columns after merging = 3276
# Merging the following columns into one: ['title_muscat', 'variety_Muscat'].
# Number of columns after merging = 3275
# Merging the following columns into one: ['title_veltliner', 'variety_Veltliner'].
# Number of columns after merging = 3274
# Merging the following columns into one: ['region-1_Western Australia', 'province_Western Australia'].
# Number of columns after merging = 3273
# Merging the following columns into one: ['title_sec', 'designation_Sec'].
# Number of columns after merging = 3272
# Merging the following columns into one: ['designation_Oregon', 'region-1_Oregon', 'province_Oregon'].
# Number of columns after merging = 3270
# Merging the following columns into one: ['title_alta', 'designation_Alta'].
# Number of columns after merging = 3269
# Merging the following columns into one: ['title_chianti', 'region-1_Chianti'].
# Number of columns after merging = 3268
# Merging the following columns into one: ['title_blaufränkisch', 'variety_Blaufränkisch'].
# Number of columns after merging = 3267
# Merging the following columns into one: ['title_crianza', 'designation_Crianza'].
# Number of columns after merging = 3266
# Merging the following columns into one: ['title_gewürztraminer', 'variety_Gewürztraminer'].
# Number of columns after merging = 3265
# Merging the following columns into one: ['title_petite', 'variety_Petite'].
# Number of columns after merging = 3264
# Merging the following columns into one: ['region-1_Missouri', 'province_Missouri'].
# Number of columns after merging = 3263
# Merging the following columns into one: ['title_portugal', 'country_Portugal'].
# Number of columns after merging = 3262
# Merging the following columns into one: ['designation_Made With Organic Grapes', 'designation_Made with Organic Grapes'].
# Number of columns after merging = 3261
# Merging the following columns into one: ['title_riesling', 'variety_Riesling'].
# Number of columns after merging = 3260
# Merging the following columns into one: ['title_bianchi', 'winery_Bianchi'].
# Number of columns after merging = 3259
# Merging the following columns into one: ['region-1_Victoria', 'province_Victoria'].
# Number of columns after merging = 3258
# Merging the following columns into one: ['region-1_Virginia', 'province_Virginia'].
# Number of columns after merging = 3257
# Merging the following columns into one: ['title_organic', 'designation_Organic'].
# Number of columns after merging = 3256
# Merging the following columns into one: ['title_noir', 'variety_Noir'].
# Number of columns after merging = 3255
# Merging the following columns into one: ['region-1_Long Island', 'region-2_Long Island'].
# Number of columns after merging = 3254
# Merging the following columns into one: ['title_signature', 'designation_Signature'].
# Number of columns after merging = 3253
# Merging the following columns into one: ['title_barolo', 'region-1_Barolo'].
# Number of columns after merging = 3252
# Merging the following columns into one: ['title_unfiltered', 'designation_Unfiltered'].
# Number of columns after merging = 3251
# Merging the following columns into one: ['title_spätlese', 'designation_Spätlese'].
# Number of columns after merging = 3250
# Merging the following columns into one: ['region-1_Southern Oregon', 'region-2_Southern Oregon'].
# Number of columns after merging = 3249
# Merging the following columns into one: ['region-1_Argentina', 'country_Argentina'].
# Number of columns after merging = 3248
# Merging the following columns into one: ['title_rosso', 'designation_Rosso'].
# Number of columns after merging = 3247
# Merging the following columns into one: ['title_selección', 'designation_Selección'].
# Number of columns after merging = 3246
# Merging the following columns into one: ['title_classic', 'designation_Classic'].
# Number of columns after merging = 3245
# Merging the following columns into one: ['title_tinto', 'designation_Tinto'].
# Number of columns after merging = 3244
# Merging the following columns into one: ['province_Lebanon', 'country_Lebanon'].
# Number of columns after merging = 3243
# Merging the following columns into one: ['title_syrah', 'variety_Syrah', 'designation_Syrah'].
# Number of columns after merging = 3241
# Merging the following columns into one: ['variety_Port', 'province_Port'].
# Number of columns after merging = 3240
# Merging the following columns into one: ['title_friulano', 'variety_Friulano'].
# Number of columns after merging = 3239
# Merging the following columns into one: ['title_estate', 'designation_Estate'].
# Number of columns after merging = 3238
# Merging the following columns into one: ['title_toro', 'variety_Toro', 'region-1_Toro'].
# Number of columns after merging = 3236
# Merging the following columns into one: ['title_vintage', 'designation_Vintage'].
# Number of columns after merging = 3235
# Merging the following columns into one: ['title_branco', 'designation_Branco'].
# Number of columns after merging = 3234
# Merging the following columns into one: ['region-1_Veneto', 'province_Veneto'].
# Number of columns after merging = 3233
# Merging the following columns into one: ['title_brut', 'designation_Brut'].
# Number of columns after merging = 3232
# Merging the following columns into one: ['title_unoaked', 'designation_Unoaked'].
# Number of columns after merging = 3231
# Merging the following columns into one: ['title_chenin', 'variety_Chenin'].
# Number of columns after merging = 3230
# Merging the following columns into one: ['winery_Chalk Hill', 'region-1_Chalk Hill'].
# Number of columns after merging = 3229
# Merging the following columns into one: ['title_roble', 'designation_Roble'].
# Number of columns after merging = 3228
# Merging the following columns into one: ['province_New Zealand', 'country_New Zealand'].
# Number of columns after merging = 3227
# Merging the following columns into one: ['province_Austria', 'country_Austria'].
# Number of columns after merging = 3226
# Merging the following columns into one: ['title_viognier', 'variety_Viognier'].
# Number of columns after merging = 3225
# Merging the following columns into one: ['title_gran', 'designation_Gran'].
# Number of columns after merging = 3224
# Merging the following columns into one: ['title_montepulciano', 'variety_Montepulciano'].
# Number of columns after merging = 3223
# Merging the following columns into one: ['title_reserva', 'designation_Reserva'].
# Number of columns after merging = 3222
# Merging the following columns into one: ['province_England', 'country_England'].
# Number of columns after merging = 3221
# Merging the following columns into one: ['title_testarossa', 'winery_Testarossa'].
# Number of columns after merging = 3220
# Merging the following columns into one: ['title_premium', 'designation_Premium'].
# Number of columns after merging = 3219
# Merging the following columns into one: ['title_sangiovese', 'variety_Sangiovese'].
# Number of columns after merging = 3218
# Merging the following columns into one: ['province_Ukraine', 'country_Ukraine'].
# Number of columns after merging = 3217
# Merging the following columns into one: ['winery_Wellington', 'province_Wellington'].
# Number of columns after merging = 3216
# Merging the following columns into one: ['title_montes', 'winery_Montes'].
# Number of columns after merging = 3215
# Merging the following columns into one: ['region-1_Piedmont', 'province_Piedmont'].
# Number of columns after merging = 3214
# Merging the following columns into one: ['title_trocken', 'designation_Trocken'].
# Number of columns after merging = 3213
# Merging the following columns into one: ['title_tannat', 'variety_Tannat'].
# Number of columns after merging = 3212
# Merging the following columns into one: ['region-1_Italy', 'country_Italy'].
# Number of columns after merging = 3211
# Merging the following columns into one: ['province_Chile', 'country_Chile'].
# Number of columns after merging = 3210
# Merging the following columns into one: ['region-1_Finger Lakes', 'region-2_Finger Lakes'].
# Number of columns after merging = 3209
# Merging the following columns into one: ['title_semillon', 'variety_Semillon'].
# Number of columns after merging = 3208
# Merging the following columns into one: ['region-1_Willamette Valley', 'region-2_Willamette Valley'].
# Number of columns after merging = 3207
# Merging the following columns into one: ['title_sirah', 'variety_Sirah'].
# Number of columns after merging = 3206
# Merging the following columns into one: ['title_tempranillo', 'variety_Tempranillo'].
# Number of columns after merging = 3205
# Merging the following columns into one: ['title_rosato', 'designation_Rosato'].
# Number of columns after merging = 3204
# Merging the following columns into one: ['title_franc', 'variety_Franc'].
# Number of columns after merging = 3203
# Merging the following columns into one: ['title_bella', 'winery_Bella'].
# Number of columns after merging = 3202
# Merging the following columns into one: ['region-1_North Coast', 'region-2_North Coast'].
# Number of columns after merging = 3201
# Merging the following columns into one: ['title_hall', 'winery_Hall'].
# Number of columns after merging = 3200
# Merging the following columns into one: ['title_petit', 'variety_Petit'].
# Number of columns after merging = 3199
# Merging the following columns into one: ['title_zweigelt', 'variety_Zweigelt'].
# Number of columns after merging = 3198
# Merging the following columns into one: ['title_bourgogne', 'region-1_Bourgogne'].
# Number of columns after merging = 3197
# Merging the following columns into one: ['province_Moldova', 'country_Moldova'].
# Number of columns after merging = 3196
# Merging the following columns into one: ['title_mencía', 'variety_Mencía'].
# Number of columns after merging = 3195
# Merging the following columns into one: ['region-1_Colorado', 'province_Colorado'].
# Number of columns after merging = 3194
# Merging the following columns into one: ['title_nebbiolo', 'variety_Nebbiolo'].
# Number of columns after merging = 3193
# Merging the following columns into one: ['title_verdejo', 'variety_Verdejo'].
# Number of columns after merging = 3192
# Merging the following columns into one: ['region-1_Tasmania', 'province_Tasmania'].
# Number of columns after merging = 3191
# Merging the following columns into one: ['region-1_Beaujolais', 'province_Beaujolais'].
# Number of columns after merging = 3190
# Merging the following columns into one: ['title_domaine', 'designation_Domaine'].
# Number of columns after merging = 3189
# Merging the following columns into one: ['title_touriga', 'variety_Touriga'].
# Number of columns after merging = 3188
# Merging the following columns into one: ['region-1_Alsace', 'province_Alsace'].
# Number of columns after merging = 3187
# Merging the following columns into one: ['title_rouge', 'designation_Rouge'].
# Number of columns after merging = 3186
# Merging the following columns into one: ['designation_Loire Valley', 'province_Loire Valley'].
# Number of columns after merging = 3185
# Merging the following columns into one: ['title_tradition', 'designation_Tradition'].
# Number of columns after merging = 3184
# Merging the following columns into one: ['title_sparkling', 'variety_Sparkling'].
# Number of columns after merging = 3183
# Merging the following columns into one: ['title_viura', 'variety_Viura'].
# Number of columns after merging = 3182
# Merging the following columns into one: ['title_sonoma', 'region-2_Sonoma'].
# Number of columns after merging = 3181
# Merging the following columns into one: ['title_zinfandel', 'variety_Zinfandel'].
# Number of columns after merging = 3180
# Merging the following columns into one: ['title_grüner', 'variety_Grüner'].
# Number of columns after merging = 3179
# Merging the following columns into one: ['title_gris', 'variety_Gris'].
# Number of columns after merging = 3178
# Merging the following columns into one: ['title_sauvignon', 'variety_Sauvignon'].
# Number of columns after merging = 3177
# Merging the following columns into one: ['title_rosado', 'designation_Rosado'].
# Number of columns after merging = 3176
# Merging the following columns into one: ['region-1_Texas', 'province_Texas'].
# Number of columns after merging = 3175
# Merging the following columns into one: ['title_prestige', 'designation_Prestige'].
# Number of columns after merging = 3174
# Merging the following columns into one: ['title_select', 'designation_Select'].
# Number of columns after merging = 3173
# Merging the following columns into one: ['title_barbera', 'variety_Barbera'].
# Number of columns after merging = 3172
# Merging the following columns into one: ['title_mourvèdre', 'variety_Mourvèdre'].
# Number of columns after merging = 3171
# Merging the following columns into one: ['region-1_Napa-Sonoma', 'region-2_Napa-Sonoma'].
# Number of columns after merging = 3170
# Merging the following columns into one: ['title_rosé', 'variety_Rosé', 'designation_Rosé'].
# Number of columns after merging = 3168
# Merging the following columns into one: ['region-1_Spain', 'country_Spain'].
# Number of columns after merging = 3167
# Merging the following columns into one: ['region-2_Central Valley', 'province_Central Valley'].
# Number of columns after merging = 3166
# Merging the following columns into one: ['title_valpolicella', 'region-1_Valpolicella'].
# Number of columns after merging = 3165
# Merging the following columns into one: ['province_Turkey', 'country_Turkey'].
# Number of columns after merging = 3164
# Merging the following columns into one: ['title_aglianico', 'variety_Aglianico'].
# Number of columns after merging = 3163
# Merging the following columns into one: ['title_nacional', 'variety_Nacional'].
# Number of columns after merging = 3162
# Merging the following columns into one: ['title_vermentino', 'variety_Vermentino'].
# Number of columns after merging = 3161
# Merging the following columns into one: ['title_blanc', 'variety_Blanc', 'designation_Blanc'].
# Number of columns after merging = 3159
# Merging the following columns into one: ['title_terroir', 'designation_Terroir'].
# Number of columns after merging = 3158
# Merging the following columns into one: ['province_Georgia', 'country_Georgia'].
# Number of columns after merging = 3157
# Merging the following columns into one: ['title_colheita', 'designation_Colheita'].
# Number of columns after merging = 3156
# Merging the following columns into one: ['title_heritage', 'designation_Heritage'].
# Number of columns after merging = 3155
# Merging the following columns into one: ['title_auslese', 'designation_Auslese'].
# Number of columns after merging = 3154
# Merging the following columns into one: ['title_moscato', 'variety_Moscato'].
# Number of columns after merging = 3153
# Merging the following columns into one: ['title_siduri', 'winery_Siduri'].
# Number of columns after merging = 3152
# Merging the following columns into one: ['variety_Prosecco', 'region-1_Prosecco'].
# Number of columns after merging = 3151
# Merging the following columns into one: ['province_Germany', 'country_Germany'].
# Number of columns after merging = 3150
# Merging the following columns into one: ['province_Greece', 'country_Greece'].
# Number of columns after merging = 3149
# Merging the following columns into one: ['region-1_South Coast', 'region-2_South Coast'].
# Number of columns after merging = 3148
# Merging the following columns into one: ['region-1_Australia', 'country_Australia'].
# Number of columns after merging = 3147
# Merging the following columns into one: ['province_Uruguay', 'country_Uruguay'].
# Number of columns after merging = 3146
# Merging the following columns into one: ['title_monastrell', 'variety_Monastrell'].
# Number of columns after merging = 3145
# Merging the following columns into one: ['title_cabernet', 'variety_Cabernet'].
# Number of columns after merging = 3144
# Merging the following columns into one: ['title_sweet', 'designation_Sweet'].
# Number of columns after merging = 3143
# Merging the following columns into one: ['title_napa', 'region-2_Napa'].
# Number of columns after merging = 3142
# Merging the following columns into one: ['province_Romania', 'country_Romania'].
# Number of columns after merging = 3141
# Merging the following columns into one: ['title_torrontés', 'variety_Torrontés'].
# Number of columns after merging = 3140
# Merging the following columns into one: ['title_white', 'variety_White', 'variety_white', 'designation_White'].
# Number of columns after merging = 3137
# Merging the following columns into one: ['region-1_Michigan', 'province_Michigan'].
# Number of columns after merging = 3136
# Merging the following columns into one: ['title_grenache', 'variety_Grenache', 'designation_Grenache'].
# Number of columns after merging = 3134
# Merging the following columns into one: ['title_barbaresco', 'region-1_Barbaresco'].
# Number of columns after merging = 3133
# Merging the following columns into one: ['title_riserva', 'designation_Riserva'].
# Number of columns after merging = 3132
# Merging the following columns into one: ['title_ridge', 'winery_Ridge'].
# Number of columns after merging = 3131
# Merging the following columns into one: ['title_carmenère', 'variety_Carmenère'].
# Number of columns after merging = 3130
# Merging the following columns into one: ['region-1_California', 'province_California'].
# Number of columns after merging = 3129
# Merging the following columns into one: ['title_réserve', 'designation_Réserve'].
# Number of columns after merging = 3128
# Merging the following columns into one: ['title_bianco', 'variety_Bianco', 'designation_Bianco'].
# Number of columns after merging = 3126
# Merging the following columns into one: ['title_cuvée', 'designation_Cuvée'].
# Number of columns after merging = 3125
# Merging the following columns into one: ['title_selection', 'designation_Selection'].
# Number of columns after merging = 3124
# Merging the following columns into one: ['region-1_Idaho', 'province_Idaho'].
# Number of columns after merging = 3123
# Merging the following columns into one: ['variety_Champagne', 'region-1_Champagne', 'province_Champagne'].
# Number of columns after merging = 3121
# Merging the following columns into one: ['title_bordeaux', 'variety_Bordeaux', 'region-1_Bordeaux', 'province_Bordeaux'].
# Number of columns after merging = 3118
# Merging the following columns into one: ['title_pinotage', 'variety_Pinotage'].
# Number of columns after merging = 3117
# Merging the following columns into one: ['title_merlot', 'variety_Merlot'].
# Number of columns after merging = 3116
# Merging the following columns into one: ['title_meritage', 'variety_Meritage', 'designation_Meritage'].
# Number of columns after merging = 3114
# Merging the following columns into one: ['title_malbec', 'variety_Malbec'].
# Number of columns after merging = 3113
# Merging the following columns into one: ['province_Israel', 'country_Israel'].
# Number of columns after merging = 3112
# Merging the following columns into one: ['title_roussanne', 'variety_Roussanne'].
# Number of columns after merging = 3111
# Merging the following columns into one: ['region-1_New York', 'province_New York'].
# Number of columns after merging = 3110
# Merging the following columns into one: ['title_collection', 'designation_Collection'].
# Number of columns after merging = 3109
# Merging the following columns into one: ['title_primitivo', 'variety_Primitivo'].
# Number of columns after merging = 3108
# Merging the following columns into one: ['region-1_Arizona', 'province_Arizona'].
# Number of columns after merging = 3107
# Merging the following columns into one: ['region-1_Central Coast', 'region-2_Central Coast'].
# Number of columns after merging = 3106
# Merging the following columns into one: ['title_grigio', 'variety_Grigio'].
# Number of columns after merging = 3105
# Merging the following columns into one: ['region-1_South Australia', 'province_South Australia'].
# Number of columns after merging = 3104
# Merging the following columns into one: ['title_kabinett', 'designation_Kabinett'].
# Number of columns after merging = 3103
# Merging the following columns into one: ['title_dry', 'designation_Dry'].
# Number of columns after merging = 3102
# Merging the following columns into one: ['region-1_Sierra Foothills', 'region-2_Sierra Foothills'].
# Number of columns after merging = 3101
# Merging the following columns into one: ['title_shiraz', 'variety_Shiraz'].
# Number of columns after merging = 3100
# Merging the following columns into one: ['title_pinot', 'variety_Pinot'].
# Number of columns after merging = 3099
# Merging the following columns into one: ['region-1_Pennsylvania', 'province_Pennsylvania'].
# Number of columns after merging = 3098
# Merging the following columns into one: ['title_reserve', 'designation_Reserve'].
# Number of columns after merging = 3097
# Merging the following columns into one: ['region-1_Washington', 'province_Washington'].
# Number of columns after merging = 3096
# Merging the following columns into one: ['title_médoc', 'region-1_Médoc'].
# Number of columns after merging = 3095
# Merging the following columns into one: ['title_albariño', 'variety_Albariño'].
# Number of columns after merging = 3094
# Merging the following columns into one: ['title_blend', 'variety_Blend', 'variety_blend'].
# Number of columns after merging = 3092
# Merging the following columns into one: ['title_chardonnay', 'variety_Chardonnay'].
# Number of columns after merging = 3091
# Merging the following columns into one: ['title_foxen', 'winery_Foxen'].
# Number of columns after merging = 3090

# %%
X_holdout_transformed = featurize_pipeline.transform(X_holdout)
# Out:
# Calculating normalized point for each taster based on training data
# feature tokenized = title, output dataframe shape = (12098, 701)
# feature tokenized = variety, output dataframe shape = (12098, 788)
# feature onehotted = winery, output dataframe shape = (12098, 1907)
# feature onehotted = designation, output dataframe shape = (12098, 2427)
# feature onehotted = region-1, output dataframe shape = (12098, 3011)
# feature onehotted = region-2, output dataframe shape = (12098, 3026)
# feature onehotted = province, output dataframe shape = (12098, 3235)
# feature onehotted = country, output dataframe shape = (12098, 3266)
# feature onehotted = taster-name, output dataframe shape = (12098, 3283)
# Merging the following raw columns: {'garnacha', 'red', 'nero', 'verdot', 'new mexico', 'muscat', 'veltliner', 'western australia', 'sec', 'oregon', 'alta', 'chianti', 'blaufränkisch', 'crianza', 'gewürztraminer', 'petite', 'missouri', 'portugal', 'made with organic grapes', 'riesling', 'bianchi', 'victoria', 'virginia', 'organic', 'noir', 'long island', 'signature', 'barolo', 'unfiltered', 'spätlese', 'southern oregon', 'argentina', 'rosso', 'selección', 'classic', 'tinto', 'lebanon', 'syrah', 'port', 'friulano', 'estate', 'toro', 'vintage', 'branco', 'veneto', 'brut', 'unoaked', 'chenin', 'chalk hill', 'roble', 'new zealand', 'austria', 'viognier', 'gran', 'montepulciano', 'reserva', 'england', 'testarossa', 'premium', 'sangiovese', 'ukraine', 'wellington', 'montes', 'piedmont', 'trocken', 'tannat', 'italy', 'chile', 'finger lakes', 'semillon', 'willamette valley', 'sirah', 'tempranillo', 'rosato', 'franc', 'bella', 'north coast', 'hall', 'petit', 'zweigelt', 'bourgogne', 'moldova', 'mencía', 'colorado', 'nebbiolo', 'verdejo', 'tasmania', 'beaujolais', 'domaine', 'touriga', 'alsace', 'rouge', 'loire valley', 'tradition', 'sparkling', 'viura', 'sonoma', 'zinfandel', 'grüner', 'gris', 'sauvignon', 'rosado', 'texas', 'prestige', 'select', 'barbera', 'mourvèdre', 'napa-sonoma', 'rosé', 'spain', 'central valley', 'valpolicella', 'turkey', 'aglianico', 'nacional', 'vermentino', 'blanc', 'terroir', 'georgia', 'colheita', 'heritage', 'auslese', 'moscato', 'siduri', 'prosecco', 'germany', 'greece', 'south coast', 'australia', 'uruguay', 'monastrell', 'cabernet', 'sweet', 'napa', 'romania', 'torrontés', 'white', 'michigan', 'grenache', 'barbaresco', 'riserva', 'ridge', 'carmenère', 'california', 'réserve', 'bianco', 'cuvée', 'selection', 'idaho', 'champagne', 'bordeaux', 'pinotage', 'merlot', 'meritage', 'malbec', 'israel', 'roussanne', 'new york', 'collection', 'primitivo', 'arizona', 'central coast', 'grigio', 'south australia', 'kabinett', 'dry', 'sierra foothills', 'shiraz', 'pinot', 'pennsylvania', 'reserve', 'washington', 'médoc', 'albariño', 'blend', 'chardonnay', 'foxen'}
# Merging the following columns into one: ['title_garnacha', 'variety_Garnacha', 'designation_Garnacha'].
# Number of columns after merging = 3281
# Merging the following columns into one: ['title_red', 'variety_Red', 'designation_Red'].
# Number of columns after merging = 3279
# Merging the following columns into one: ['title_nero', 'variety_Nero'].
# Number of columns after merging = 3278
# Merging the following columns into one: ['title_verdot', 'variety_Verdot'].
# Number of columns after merging = 3277
# Merging the following columns into one: ['region-1_New Mexico', 'province_New Mexico'].
# Number of columns after merging = 3276
# Merging the following columns into one: ['title_muscat', 'variety_Muscat'].
# Number of columns after merging = 3275
# Merging the following columns into one: ['title_veltliner', 'variety_Veltliner'].
# Number of columns after merging = 3274
# Merging the following columns into one: ['region-1_Western Australia', 'province_Western Australia'].
# Number of columns after merging = 3273
# Merging the following columns into one: ['title_sec', 'designation_Sec'].
# Number of columns after merging = 3272
# Merging the following columns into one: ['designation_Oregon', 'region-1_Oregon', 'province_Oregon'].
# Number of columns after merging = 3270
# Merging the following columns into one: ['title_alta', 'designation_Alta'].
# Number of columns after merging = 3269
# Merging the following columns into one: ['title_chianti', 'region-1_Chianti'].
# Number of columns after merging = 3268
# Merging the following columns into one: ['title_blaufränkisch', 'variety_Blaufränkisch'].
# Number of columns after merging = 3267
# Merging the following columns into one: ['title_crianza', 'designation_Crianza'].
# Number of columns after merging = 3266
# Merging the following columns into one: ['title_gewürztraminer', 'variety_Gewürztraminer'].
# Number of columns after merging = 3265
# Merging the following columns into one: ['title_petite', 'variety_Petite'].
# Number of columns after merging = 3264
# Merging the following columns into one: ['region-1_Missouri', 'province_Missouri'].
# Number of columns after merging = 3263
# Merging the following columns into one: ['title_portugal', 'country_Portugal'].
# Number of columns after merging = 3262
# Merging the following columns into one: ['designation_Made With Organic Grapes', 'designation_Made with Organic Grapes'].
# Number of columns after merging = 3261
# Merging the following columns into one: ['title_riesling', 'variety_Riesling'].
# Number of columns after merging = 3260
# Merging the following columns into one: ['title_bianchi', 'winery_Bianchi'].
# Number of columns after merging = 3259
# Merging the following columns into one: ['region-1_Victoria', 'province_Victoria'].
# Number of columns after merging = 3258
# Merging the following columns into one: ['region-1_Virginia', 'province_Virginia'].
# Number of columns after merging = 3257
# Merging the following columns into one: ['title_organic', 'designation_Organic'].
# Number of columns after merging = 3256
# Merging the following columns into one: ['title_noir', 'variety_Noir'].
# Number of columns after merging = 3255
# Merging the following columns into one: ['region-1_Long Island', 'region-2_Long Island'].
# Number of columns after merging = 3254
# Merging the following columns into one: ['title_signature', 'designation_Signature'].
# Number of columns after merging = 3253
# Merging the following columns into one: ['title_barolo', 'region-1_Barolo'].
# Number of columns after merging = 3252
# Merging the following columns into one: ['title_unfiltered', 'designation_Unfiltered'].
# Number of columns after merging = 3251
# Merging the following columns into one: ['title_spätlese', 'designation_Spätlese'].
# Number of columns after merging = 3250
# Merging the following columns into one: ['region-1_Southern Oregon', 'region-2_Southern Oregon'].
# Number of columns after merging = 3249
# Merging the following columns into one: ['region-1_Argentina', 'country_Argentina'].
# Number of columns after merging = 3248
# Merging the following columns into one: ['title_rosso', 'designation_Rosso'].
# Number of columns after merging = 3247
# Merging the following columns into one: ['title_selección', 'designation_Selección'].
# Number of columns after merging = 3246
# Merging the following columns into one: ['title_classic', 'designation_Classic'].
# Number of columns after merging = 3245
# Merging the following columns into one: ['title_tinto', 'designation_Tinto'].
# Number of columns after merging = 3244
# Merging the following columns into one: ['province_Lebanon', 'country_Lebanon'].
# Number of columns after merging = 3243
# Merging the following columns into one: ['title_syrah', 'variety_Syrah', 'designation_Syrah'].
# Number of columns after merging = 3241
# Merging the following columns into one: ['variety_Port', 'province_Port'].
# Number of columns after merging = 3240
# Merging the following columns into one: ['title_friulano', 'variety_Friulano'].
# Number of columns after merging = 3239
# Merging the following columns into one: ['title_estate', 'designation_Estate'].
# Number of columns after merging = 3238
# Merging the following columns into one: ['title_toro', 'variety_Toro', 'region-1_Toro'].
# Number of columns after merging = 3236
# Merging the following columns into one: ['title_vintage', 'designation_Vintage'].
# Number of columns after merging = 3235
# Merging the following columns into one: ['title_branco', 'designation_Branco'].
# Number of columns after merging = 3234
# Merging the following columns into one: ['region-1_Veneto', 'province_Veneto'].
# Number of columns after merging = 3233
# Merging the following columns into one: ['title_brut', 'designation_Brut'].
# Number of columns after merging = 3232
# Merging the following columns into one: ['title_unoaked', 'designation_Unoaked'].
# Number of columns after merging = 3231
# Merging the following columns into one: ['title_chenin', 'variety_Chenin'].
# Number of columns after merging = 3230
# Merging the following columns into one: ['winery_Chalk Hill', 'region-1_Chalk Hill'].
# Number of columns after merging = 3229
# Merging the following columns into one: ['title_roble', 'designation_Roble'].
# Number of columns after merging = 3228
# Merging the following columns into one: ['province_New Zealand', 'country_New Zealand'].
# Number of columns after merging = 3227
# Merging the following columns into one: ['province_Austria', 'country_Austria'].
# Number of columns after merging = 3226
# Merging the following columns into one: ['title_viognier', 'variety_Viognier'].
# Number of columns after merging = 3225
# Merging the following columns into one: ['title_gran', 'designation_Gran'].
# Number of columns after merging = 3224
# Merging the following columns into one: ['title_montepulciano', 'variety_Montepulciano'].
# Number of columns after merging = 3223
# Merging the following columns into one: ['title_reserva', 'designation_Reserva'].
# Number of columns after merging = 3222
# Merging the following columns into one: ['province_England', 'country_England'].
# Number of columns after merging = 3221
# Merging the following columns into one: ['title_testarossa', 'winery_Testarossa'].
# Number of columns after merging = 3220
# Merging the following columns into one: ['title_premium', 'designation_Premium'].
# Number of columns after merging = 3219
# Merging the following columns into one: ['title_sangiovese', 'variety_Sangiovese'].
# Number of columns after merging = 3218
# Merging the following columns into one: ['province_Ukraine', 'country_Ukraine'].
# Number of columns after merging = 3217
# Merging the following columns into one: ['winery_Wellington', 'province_Wellington'].
# Number of columns after merging = 3216
# Merging the following columns into one: ['title_montes', 'winery_Montes'].
# Number of columns after merging = 3215
# Merging the following columns into one: ['region-1_Piedmont', 'province_Piedmont'].
# Number of columns after merging = 3214
# Merging the following columns into one: ['title_trocken', 'designation_Trocken'].
# Number of columns after merging = 3213
# Merging the following columns into one: ['title_tannat', 'variety_Tannat'].
# Number of columns after merging = 3212
# Merging the following columns into one: ['region-1_Italy', 'country_Italy'].
# Number of columns after merging = 3211
# Merging the following columns into one: ['province_Chile', 'country_Chile'].
# Number of columns after merging = 3210
# Merging the following columns into one: ['region-1_Finger Lakes', 'region-2_Finger Lakes'].
# Number of columns after merging = 3209
# Merging the following columns into one: ['title_semillon', 'variety_Semillon'].
# Number of columns after merging = 3208
# Merging the following columns into one: ['region-1_Willamette Valley', 'region-2_Willamette Valley'].
# Number of columns after merging = 3207
# Merging the following columns into one: ['title_sirah', 'variety_Sirah'].
# Number of columns after merging = 3206
# Merging the following columns into one: ['title_tempranillo', 'variety_Tempranillo'].
# Number of columns after merging = 3205
# Merging the following columns into one: ['title_rosato', 'designation_Rosato'].
# Number of columns after merging = 3204
# Merging the following columns into one: ['title_franc', 'variety_Franc'].
# Number of columns after merging = 3203
# Merging the following columns into one: ['title_bella', 'winery_Bella'].
# Number of columns after merging = 3202
# Merging the following columns into one: ['region-1_North Coast', 'region-2_North Coast'].
# Number of columns after merging = 3201
# Merging the following columns into one: ['title_hall', 'winery_Hall'].
# Number of columns after merging = 3200
# Merging the following columns into one: ['title_petit', 'variety_Petit'].
# Number of columns after merging = 3199
# Merging the following columns into one: ['title_zweigelt', 'variety_Zweigelt'].
# Number of columns after merging = 3198
# Merging the following columns into one: ['title_bourgogne', 'region-1_Bourgogne'].
# Number of columns after merging = 3197
# Merging the following columns into one: ['province_Moldova', 'country_Moldova'].
# Number of columns after merging = 3196
# Merging the following columns into one: ['title_mencía', 'variety_Mencía'].
# Number of columns after merging = 3195
# Merging the following columns into one: ['region-1_Colorado', 'province_Colorado'].
# Number of columns after merging = 3194
# Merging the following columns into one: ['title_nebbiolo', 'variety_Nebbiolo'].
# Number of columns after merging = 3193
# Merging the following columns into one: ['title_verdejo', 'variety_Verdejo'].
# Number of columns after merging = 3192
# Merging the following columns into one: ['region-1_Tasmania', 'province_Tasmania'].
# Number of columns after merging = 3191
# Merging the following columns into one: ['region-1_Beaujolais', 'province_Beaujolais'].
# Number of columns after merging = 3190
# Merging the following columns into one: ['title_domaine', 'designation_Domaine'].
# Number of columns after merging = 3189
# Merging the following columns into one: ['title_touriga', 'variety_Touriga'].
# Number of columns after merging = 3188
# Merging the following columns into one: ['region-1_Alsace', 'province_Alsace'].
# Number of columns after merging = 3187
# Merging the following columns into one: ['title_rouge', 'designation_Rouge'].
# Number of columns after merging = 3186
# Merging the following columns into one: ['designation_Loire Valley', 'province_Loire Valley'].
# Number of columns after merging = 3185
# Merging the following columns into one: ['title_tradition', 'designation_Tradition'].
# Number of columns after merging = 3184
# Merging the following columns into one: ['title_sparkling', 'variety_Sparkling'].
# Number of columns after merging = 3183
# Merging the following columns into one: ['title_viura', 'variety_Viura'].
# Number of columns after merging = 3182
# Merging the following columns into one: ['title_sonoma', 'region-2_Sonoma'].
# Number of columns after merging = 3181
# Merging the following columns into one: ['title_zinfandel', 'variety_Zinfandel'].
# Number of columns after merging = 3180
# Merging the following columns into one: ['title_grüner', 'variety_Grüner'].
# Number of columns after merging = 3179
# Merging the following columns into one: ['title_gris', 'variety_Gris'].
# Number of columns after merging = 3178
# Merging the following columns into one: ['title_sauvignon', 'variety_Sauvignon'].
# Number of columns after merging = 3177
# Merging the following columns into one: ['title_rosado', 'designation_Rosado'].
# Number of columns after merging = 3176
# Merging the following columns into one: ['region-1_Texas', 'province_Texas'].
# Number of columns after merging = 3175
# Merging the following columns into one: ['title_prestige', 'designation_Prestige'].
# Number of columns after merging = 3174
# Merging the following columns into one: ['title_select', 'designation_Select'].
# Number of columns after merging = 3173
# Merging the following columns into one: ['title_barbera', 'variety_Barbera'].
# Number of columns after merging = 3172
# Merging the following columns into one: ['title_mourvèdre', 'variety_Mourvèdre'].
# Number of columns after merging = 3171
# Merging the following columns into one: ['region-1_Napa-Sonoma', 'region-2_Napa-Sonoma'].
# Number of columns after merging = 3170
# Merging the following columns into one: ['title_rosé', 'variety_Rosé', 'designation_Rosé'].
# Number of columns after merging = 3168
# Merging the following columns into one: ['region-1_Spain', 'country_Spain'].
# Number of columns after merging = 3167
# Merging the following columns into one: ['region-2_Central Valley', 'province_Central Valley'].
# Number of columns after merging = 3166
# Merging the following columns into one: ['title_valpolicella', 'region-1_Valpolicella'].
# Number of columns after merging = 3165
# Merging the following columns into one: ['province_Turkey', 'country_Turkey'].
# Number of columns after merging = 3164
# Merging the following columns into one: ['title_aglianico', 'variety_Aglianico'].
# Number of columns after merging = 3163
# Merging the following columns into one: ['title_nacional', 'variety_Nacional'].
# Number of columns after merging = 3162
# Merging the following columns into one: ['title_vermentino', 'variety_Vermentino'].
# Number of columns after merging = 3161
# Merging the following columns into one: ['title_blanc', 'variety_Blanc', 'designation_Blanc'].
# Number of columns after merging = 3159
# Merging the following columns into one: ['title_terroir', 'designation_Terroir'].
# Number of columns after merging = 3158
# Merging the following columns into one: ['province_Georgia', 'country_Georgia'].
# Number of columns after merging = 3157
# Merging the following columns into one: ['title_colheita', 'designation_Colheita'].
# Number of columns after merging = 3156
# Merging the following columns into one: ['title_heritage', 'designation_Heritage'].
# Number of columns after merging = 3155
# Merging the following columns into one: ['title_auslese', 'designation_Auslese'].
# Number of columns after merging = 3154
# Merging the following columns into one: ['title_moscato', 'variety_Moscato'].
# Number of columns after merging = 3153
# Merging the following columns into one: ['title_siduri', 'winery_Siduri'].
# Number of columns after merging = 3152
# Merging the following columns into one: ['variety_Prosecco', 'region-1_Prosecco'].
# Number of columns after merging = 3151
# Merging the following columns into one: ['province_Germany', 'country_Germany'].
# Number of columns after merging = 3150
# Merging the following columns into one: ['province_Greece', 'country_Greece'].
# Number of columns after merging = 3149
# Merging the following columns into one: ['region-1_South Coast', 'region-2_South Coast'].
# Number of columns after merging = 3148
# Merging the following columns into one: ['region-1_Australia', 'country_Australia'].
# Number of columns after merging = 3147
# Merging the following columns into one: ['province_Uruguay', 'country_Uruguay'].
# Number of columns after merging = 3146
# Merging the following columns into one: ['title_monastrell', 'variety_Monastrell'].
# Number of columns after merging = 3145
# Merging the following columns into one: ['title_cabernet', 'variety_Cabernet'].
# Number of columns after merging = 3144
# Merging the following columns into one: ['title_sweet', 'designation_Sweet'].
# Number of columns after merging = 3143
# Merging the following columns into one: ['title_napa', 'region-2_Napa'].
# Number of columns after merging = 3142
# Merging the following columns into one: ['province_Romania', 'country_Romania'].
# Number of columns after merging = 3141
# Merging the following columns into one: ['title_torrontés', 'variety_Torrontés'].
# Number of columns after merging = 3140
# Merging the following columns into one: ['title_white', 'variety_White', 'variety_white', 'designation_White'].
# Number of columns after merging = 3137
# Merging the following columns into one: ['region-1_Michigan', 'province_Michigan'].
# Number of columns after merging = 3136
# Merging the following columns into one: ['title_grenache', 'variety_Grenache', 'designation_Grenache'].
# Number of columns after merging = 3134
# Merging the following columns into one: ['title_barbaresco', 'region-1_Barbaresco'].
# Number of columns after merging = 3133
# Merging the following columns into one: ['title_riserva', 'designation_Riserva'].
# Number of columns after merging = 3132
# Merging the following columns into one: ['title_ridge', 'winery_Ridge'].
# Number of columns after merging = 3131
# Merging the following columns into one: ['title_carmenère', 'variety_Carmenère'].
# Number of columns after merging = 3130
# Merging the following columns into one: ['region-1_California', 'province_California'].
# Number of columns after merging = 3129
# Merging the following columns into one: ['title_réserve', 'designation_Réserve'].
# Number of columns after merging = 3128
# Merging the following columns into one: ['title_bianco', 'variety_Bianco', 'designation_Bianco'].
# Number of columns after merging = 3126
# Merging the following columns into one: ['title_cuvée', 'designation_Cuvée'].
# Number of columns after merging = 3125
# Merging the following columns into one: ['title_selection', 'designation_Selection'].
# Number of columns after merging = 3124
# Merging the following columns into one: ['region-1_Idaho', 'province_Idaho'].
# Number of columns after merging = 3123
# Merging the following columns into one: ['variety_Champagne', 'region-1_Champagne', 'province_Champagne'].
# Number of columns after merging = 3121
# Merging the following columns into one: ['title_bordeaux', 'variety_Bordeaux', 'region-1_Bordeaux', 'province_Bordeaux'].
# Number of columns after merging = 3118
# Merging the following columns into one: ['title_pinotage', 'variety_Pinotage'].
# Number of columns after merging = 3117
# Merging the following columns into one: ['title_merlot', 'variety_Merlot'].
# Number of columns after merging = 3116
# Merging the following columns into one: ['title_meritage', 'variety_Meritage', 'designation_Meritage'].
# Number of columns after merging = 3114
# Merging the following columns into one: ['title_malbec', 'variety_Malbec'].
# Number of columns after merging = 3113
# Merging the following columns into one: ['province_Israel', 'country_Israel'].
# Number of columns after merging = 3112
# Merging the following columns into one: ['title_roussanne', 'variety_Roussanne'].
# Number of columns after merging = 3111
# Merging the following columns into one: ['region-1_New York', 'province_New York'].
# Number of columns after merging = 3110
# Merging the following columns into one: ['title_collection', 'designation_Collection'].
# Number of columns after merging = 3109
# Merging the following columns into one: ['title_primitivo', 'variety_Primitivo'].
# Number of columns after merging = 3108
# Merging the following columns into one: ['region-1_Arizona', 'province_Arizona'].
# Number of columns after merging = 3107
# Merging the following columns into one: ['region-1_Central Coast', 'region-2_Central Coast'].
# Number of columns after merging = 3106
# Merging the following columns into one: ['title_grigio', 'variety_Grigio'].
# Number of columns after merging = 3105
# Merging the following columns into one: ['region-1_South Australia', 'province_South Australia'].
# Number of columns after merging = 3104
# Merging the following columns into one: ['title_kabinett', 'designation_Kabinett'].
# Number of columns after merging = 3103
# Merging the following columns into one: ['title_dry', 'designation_Dry'].
# Number of columns after merging = 3102
# Merging the following columns into one: ['region-1_Sierra Foothills', 'region-2_Sierra Foothills'].
# Number of columns after merging = 3101
# Merging the following columns into one: ['title_shiraz', 'variety_Shiraz'].
# Number of columns after merging = 3100
# Merging the following columns into one: ['title_pinot', 'variety_Pinot'].
# Number of columns after merging = 3099
# Merging the following columns into one: ['region-1_Pennsylvania', 'province_Pennsylvania'].
# Number of columns after merging = 3098
# Merging the following columns into one: ['title_reserve', 'designation_Reserve'].
# Number of columns after merging = 3097
# Merging the following columns into one: ['region-1_Washington', 'province_Washington'].
# Number of columns after merging = 3096
# Merging the following columns into one: ['title_médoc', 'region-1_Médoc'].
# Number of columns after merging = 3095
# Merging the following columns into one: ['title_albariño', 'variety_Albariño'].
# Number of columns after merging = 3094
# Merging the following columns into one: ['title_blend', 'variety_Blend', 'variety_blend'].
# Number of columns after merging = 3092
# Merging the following columns into one: ['title_chardonnay', 'variety_Chardonnay'].
# Number of columns after merging = 3091
# Merging the following columns into one: ['title_foxen', 'winery_Foxen'].
# Number of columns after merging = 3090

# %%
X_val_transformed = featurize_pipeline.transform(X_val)
# Out:
# Calculating normalized point for each taster based on training data
# feature tokenized = title, output dataframe shape = (10888, 701)
# feature tokenized = variety, output dataframe shape = (10888, 788)
# feature onehotted = winery, output dataframe shape = (10888, 1907)
# feature onehotted = designation, output dataframe shape = (10888, 2427)
# feature onehotted = region-1, output dataframe shape = (10888, 3011)
# feature onehotted = region-2, output dataframe shape = (10888, 3026)
# feature onehotted = province, output dataframe shape = (10888, 3235)
# feature onehotted = country, output dataframe shape = (10888, 3266)
# feature onehotted = taster-name, output dataframe shape = (10888, 3283)
# Merging the following raw columns: {'garnacha', 'red', 'nero', 'verdot', 'new mexico', 'muscat', 'veltliner', 'western australia', 'sec', 'oregon', 'alta', 'chianti', 'blaufränkisch', 'crianza', 'gewürztraminer', 'petite', 'missouri', 'portugal', 'made with organic grapes', 'riesling', 'bianchi', 'victoria', 'virginia', 'organic', 'noir', 'long island', 'signature', 'barolo', 'unfiltered', 'spätlese', 'southern oregon', 'argentina', 'rosso', 'selección', 'classic', 'tinto', 'lebanon', 'syrah', 'port', 'friulano', 'estate', 'toro', 'vintage', 'branco', 'veneto', 'brut', 'unoaked', 'chenin', 'chalk hill', 'roble', 'new zealand', 'austria', 'viognier', 'gran', 'montepulciano', 'reserva', 'england', 'testarossa', 'premium', 'sangiovese', 'ukraine', 'wellington', 'montes', 'piedmont', 'trocken', 'tannat', 'italy', 'chile', 'finger lakes', 'semillon', 'willamette valley', 'sirah', 'tempranillo', 'rosato', 'franc', 'bella', 'north coast', 'hall', 'petit', 'zweigelt', 'bourgogne', 'moldova', 'mencía', 'colorado', 'nebbiolo', 'verdejo', 'tasmania', 'beaujolais', 'domaine', 'touriga', 'alsace', 'rouge', 'loire valley', 'tradition', 'sparkling', 'viura', 'sonoma', 'zinfandel', 'grüner', 'gris', 'sauvignon', 'rosado', 'texas', 'prestige', 'select', 'barbera', 'mourvèdre', 'napa-sonoma', 'rosé', 'spain', 'central valley', 'valpolicella', 'turkey', 'aglianico', 'nacional', 'vermentino', 'blanc', 'terroir', 'georgia', 'colheita', 'heritage', 'auslese', 'moscato', 'siduri', 'prosecco', 'germany', 'greece', 'south coast', 'australia', 'uruguay', 'monastrell', 'cabernet', 'sweet', 'napa', 'romania', 'torrontés', 'white', 'michigan', 'grenache', 'barbaresco', 'riserva', 'ridge', 'carmenère', 'california', 'réserve', 'bianco', 'cuvée', 'selection', 'idaho', 'champagne', 'bordeaux', 'pinotage', 'merlot', 'meritage', 'malbec', 'israel', 'roussanne', 'new york', 'collection', 'primitivo', 'arizona', 'central coast', 'grigio', 'south australia', 'kabinett', 'dry', 'sierra foothills', 'shiraz', 'pinot', 'pennsylvania', 'reserve', 'washington', 'médoc', 'albariño', 'blend', 'chardonnay', 'foxen'}
# Merging the following columns into one: ['title_garnacha', 'variety_Garnacha', 'designation_Garnacha'].
# Number of columns after merging = 3281
# Merging the following columns into one: ['title_red', 'variety_Red', 'designation_Red'].
# Number of columns after merging = 3279
# Merging the following columns into one: ['title_nero', 'variety_Nero'].
# Number of columns after merging = 3278
# Merging the following columns into one: ['title_verdot', 'variety_Verdot'].
# Number of columns after merging = 3277
# Merging the following columns into one: ['region-1_New Mexico', 'province_New Mexico'].
# Number of columns after merging = 3276
# Merging the following columns into one: ['title_muscat', 'variety_Muscat'].
# Number of columns after merging = 3275
# Merging the following columns into one: ['title_veltliner', 'variety_Veltliner'].
# Number of columns after merging = 3274
# Merging the following columns into one: ['region-1_Western Australia', 'province_Western Australia'].
# Number of columns after merging = 3273
# Merging the following columns into one: ['title_sec', 'designation_Sec'].
# Number of columns after merging = 3272
# Merging the following columns into one: ['designation_Oregon', 'region-1_Oregon', 'province_Oregon'].
# Number of columns after merging = 3270
# Merging the following columns into one: ['title_alta', 'designation_Alta'].
# Number of columns after merging = 3269
# Merging the following columns into one: ['title_chianti', 'region-1_Chianti'].
# Number of columns after merging = 3268
# Merging the following columns into one: ['title_blaufränkisch', 'variety_Blaufränkisch'].
# Number of columns after merging = 3267
# Merging the following columns into one: ['title_crianza', 'designation_Crianza'].
# Number of columns after merging = 3266
# Merging the following columns into one: ['title_gewürztraminer', 'variety_Gewürztraminer'].
# Number of columns after merging = 3265
# Merging the following columns into one: ['title_petite', 'variety_Petite'].
# Number of columns after merging = 3264
# Merging the following columns into one: ['region-1_Missouri', 'province_Missouri'].
# Number of columns after merging = 3263
# Merging the following columns into one: ['title_portugal', 'country_Portugal'].
# Number of columns after merging = 3262
# Merging the following columns into one: ['designation_Made With Organic Grapes', 'designation_Made with Organic Grapes'].
# Number of columns after merging = 3261
# Merging the following columns into one: ['title_riesling', 'variety_Riesling'].
# Number of columns after merging = 3260
# Merging the following columns into one: ['title_bianchi', 'winery_Bianchi'].
# Number of columns after merging = 3259
# Merging the following columns into one: ['region-1_Victoria', 'province_Victoria'].
# Number of columns after merging = 3258
# Merging the following columns into one: ['region-1_Virginia', 'province_Virginia'].
# Number of columns after merging = 3257
# Merging the following columns into one: ['title_organic', 'designation_Organic'].
# Number of columns after merging = 3256
# Merging the following columns into one: ['title_noir', 'variety_Noir'].
# Number of columns after merging = 3255
# Merging the following columns into one: ['region-1_Long Island', 'region-2_Long Island'].
# Number of columns after merging = 3254
# Merging the following columns into one: ['title_signature', 'designation_Signature'].
# Number of columns after merging = 3253
# Merging the following columns into one: ['title_barolo', 'region-1_Barolo'].
# Number of columns after merging = 3252
# Merging the following columns into one: ['title_unfiltered', 'designation_Unfiltered'].
# Number of columns after merging = 3251
# Merging the following columns into one: ['title_spätlese', 'designation_Spätlese'].
# Number of columns after merging = 3250
# Merging the following columns into one: ['region-1_Southern Oregon', 'region-2_Southern Oregon'].
# Number of columns after merging = 3249
# Merging the following columns into one: ['region-1_Argentina', 'country_Argentina'].
# Number of columns after merging = 3248
# Merging the following columns into one: ['title_rosso', 'designation_Rosso'].
# Number of columns after merging = 3247
# Merging the following columns into one: ['title_selección', 'designation_Selección'].
# Number of columns after merging = 3246
# Merging the following columns into one: ['title_classic', 'designation_Classic'].
# Number of columns after merging = 3245
# Merging the following columns into one: ['title_tinto', 'designation_Tinto'].
# Number of columns after merging = 3244
# Merging the following columns into one: ['province_Lebanon', 'country_Lebanon'].
# Number of columns after merging = 3243
# Merging the following columns into one: ['title_syrah', 'variety_Syrah', 'designation_Syrah'].
# Number of columns after merging = 3241
# Merging the following columns into one: ['variety_Port', 'province_Port'].
# Number of columns after merging = 3240
# Merging the following columns into one: ['title_friulano', 'variety_Friulano'].
# Number of columns after merging = 3239
# Merging the following columns into one: ['title_estate', 'designation_Estate'].
# Number of columns after merging = 3238
# Merging the following columns into one: ['title_toro', 'variety_Toro', 'region-1_Toro'].
# Number of columns after merging = 3236
# Merging the following columns into one: ['title_vintage', 'designation_Vintage'].
# Number of columns after merging = 3235
# Merging the following columns into one: ['title_branco', 'designation_Branco'].
# Number of columns after merging = 3234
# Merging the following columns into one: ['region-1_Veneto', 'province_Veneto'].
# Number of columns after merging = 3233
# Merging the following columns into one: ['title_brut', 'designation_Brut'].
# Number of columns after merging = 3232
# Merging the following columns into one: ['title_unoaked', 'designation_Unoaked'].
# Number of columns after merging = 3231
# Merging the following columns into one: ['title_chenin', 'variety_Chenin'].
# Number of columns after merging = 3230
# Merging the following columns into one: ['winery_Chalk Hill', 'region-1_Chalk Hill'].
# Number of columns after merging = 3229
# Merging the following columns into one: ['title_roble', 'designation_Roble'].
# Number of columns after merging = 3228
# Merging the following columns into one: ['province_New Zealand', 'country_New Zealand'].
# Number of columns after merging = 3227
# Merging the following columns into one: ['province_Austria', 'country_Austria'].
# Number of columns after merging = 3226
# Merging the following columns into one: ['title_viognier', 'variety_Viognier'].
# Number of columns after merging = 3225
# Merging the following columns into one: ['title_gran', 'designation_Gran'].
# Number of columns after merging = 3224
# Merging the following columns into one: ['title_montepulciano', 'variety_Montepulciano'].
# Number of columns after merging = 3223
# Merging the following columns into one: ['title_reserva', 'designation_Reserva'].
# Number of columns after merging = 3222
# Merging the following columns into one: ['province_England', 'country_England'].
# Number of columns after merging = 3221
# Merging the following columns into one: ['title_testarossa', 'winery_Testarossa'].
# Number of columns after merging = 3220
# Merging the following columns into one: ['title_premium', 'designation_Premium'].
# Number of columns after merging = 3219
# Merging the following columns into one: ['title_sangiovese', 'variety_Sangiovese'].
# Number of columns after merging = 3218
# Merging the following columns into one: ['province_Ukraine', 'country_Ukraine'].
# Number of columns after merging = 3217
# Merging the following columns into one: ['winery_Wellington', 'province_Wellington'].
# Number of columns after merging = 3216
# Merging the following columns into one: ['title_montes', 'winery_Montes'].
# Number of columns after merging = 3215
# Merging the following columns into one: ['region-1_Piedmont', 'province_Piedmont'].
# Number of columns after merging = 3214
# Merging the following columns into one: ['title_trocken', 'designation_Trocken'].
# Number of columns after merging = 3213
# Merging the following columns into one: ['title_tannat', 'variety_Tannat'].
# Number of columns after merging = 3212
# Merging the following columns into one: ['region-1_Italy', 'country_Italy'].
# Number of columns after merging = 3211
# Merging the following columns into one: ['province_Chile', 'country_Chile'].
# Number of columns after merging = 3210
# Merging the following columns into one: ['region-1_Finger Lakes', 'region-2_Finger Lakes'].
# Number of columns after merging = 3209
# Merging the following columns into one: ['title_semillon', 'variety_Semillon'].
# Number of columns after merging = 3208
# Merging the following columns into one: ['region-1_Willamette Valley', 'region-2_Willamette Valley'].
# Number of columns after merging = 3207
# Merging the following columns into one: ['title_sirah', 'variety_Sirah'].
# Number of columns after merging = 3206
# Merging the following columns into one: ['title_tempranillo', 'variety_Tempranillo'].
# Number of columns after merging = 3205
# Merging the following columns into one: ['title_rosato', 'designation_Rosato'].
# Number of columns after merging = 3204
# Merging the following columns into one: ['title_franc', 'variety_Franc'].
# Number of columns after merging = 3203
# Merging the following columns into one: ['title_bella', 'winery_Bella'].
# Number of columns after merging = 3202
# Merging the following columns into one: ['region-1_North Coast', 'region-2_North Coast'].
# Number of columns after merging = 3201
# Merging the following columns into one: ['title_hall', 'winery_Hall'].
# Number of columns after merging = 3200
# Merging the following columns into one: ['title_petit', 'variety_Petit'].
# Number of columns after merging = 3199
# Merging the following columns into one: ['title_zweigelt', 'variety_Zweigelt'].
# Number of columns after merging = 3198
# Merging the following columns into one: ['title_bourgogne', 'region-1_Bourgogne'].
# Number of columns after merging = 3197
# Merging the following columns into one: ['province_Moldova', 'country_Moldova'].
# Number of columns after merging = 3196
# Merging the following columns into one: ['title_mencía', 'variety_Mencía'].
# Number of columns after merging = 3195
# Merging the following columns into one: ['region-1_Colorado', 'province_Colorado'].
# Number of columns after merging = 3194
# Merging the following columns into one: ['title_nebbiolo', 'variety_Nebbiolo'].
# Number of columns after merging = 3193
# Merging the following columns into one: ['title_verdejo', 'variety_Verdejo'].
# Number of columns after merging = 3192
# Merging the following columns into one: ['region-1_Tasmania', 'province_Tasmania'].
# Number of columns after merging = 3191
# Merging the following columns into one: ['region-1_Beaujolais', 'province_Beaujolais'].
# Number of columns after merging = 3190
# Merging the following columns into one: ['title_domaine', 'designation_Domaine'].
# Number of columns after merging = 3189
# Merging the following columns into one: ['title_touriga', 'variety_Touriga'].
# Number of columns after merging = 3188
# Merging the following columns into one: ['region-1_Alsace', 'province_Alsace'].
# Number of columns after merging = 3187
# Merging the following columns into one: ['title_rouge', 'designation_Rouge'].
# Number of columns after merging = 3186
# Merging the following columns into one: ['designation_Loire Valley', 'province_Loire Valley'].
# Number of columns after merging = 3185
# Merging the following columns into one: ['title_tradition', 'designation_Tradition'].
# Number of columns after merging = 3184
# Merging the following columns into one: ['title_sparkling', 'variety_Sparkling'].
# Number of columns after merging = 3183
# Merging the following columns into one: ['title_viura', 'variety_Viura'].
# Number of columns after merging = 3182
# Merging the following columns into one: ['title_sonoma', 'region-2_Sonoma'].
# Number of columns after merging = 3181
# Merging the following columns into one: ['title_zinfandel', 'variety_Zinfandel'].
# Number of columns after merging = 3180
# Merging the following columns into one: ['title_grüner', 'variety_Grüner'].
# Number of columns after merging = 3179
# Merging the following columns into one: ['title_gris', 'variety_Gris'].
# Number of columns after merging = 3178
# Merging the following columns into one: ['title_sauvignon', 'variety_Sauvignon'].
# Number of columns after merging = 3177
# Merging the following columns into one: ['title_rosado', 'designation_Rosado'].
# Number of columns after merging = 3176
# Merging the following columns into one: ['region-1_Texas', 'province_Texas'].
# Number of columns after merging = 3175
# Merging the following columns into one: ['title_prestige', 'designation_Prestige'].
# Number of columns after merging = 3174
# Merging the following columns into one: ['title_select', 'designation_Select'].
# Number of columns after merging = 3173
# Merging the following columns into one: ['title_barbera', 'variety_Barbera'].
# Number of columns after merging = 3172
# Merging the following columns into one: ['title_mourvèdre', 'variety_Mourvèdre'].
# Number of columns after merging = 3171
# Merging the following columns into one: ['region-1_Napa-Sonoma', 'region-2_Napa-Sonoma'].
# Number of columns after merging = 3170
# Merging the following columns into one: ['title_rosé', 'variety_Rosé', 'designation_Rosé'].
# Number of columns after merging = 3168
# Merging the following columns into one: ['region-1_Spain', 'country_Spain'].
# Number of columns after merging = 3167
# Merging the following columns into one: ['region-2_Central Valley', 'province_Central Valley'].
# Number of columns after merging = 3166
# Merging the following columns into one: ['title_valpolicella', 'region-1_Valpolicella'].
# Number of columns after merging = 3165
# Merging the following columns into one: ['province_Turkey', 'country_Turkey'].
# Number of columns after merging = 3164
# Merging the following columns into one: ['title_aglianico', 'variety_Aglianico'].
# Number of columns after merging = 3163
# Merging the following columns into one: ['title_nacional', 'variety_Nacional'].
# Number of columns after merging = 3162
# Merging the following columns into one: ['title_vermentino', 'variety_Vermentino'].
# Number of columns after merging = 3161
# Merging the following columns into one: ['title_blanc', 'variety_Blanc', 'designation_Blanc'].
# Number of columns after merging = 3159
# Merging the following columns into one: ['title_terroir', 'designation_Terroir'].
# Number of columns after merging = 3158
# Merging the following columns into one: ['province_Georgia', 'country_Georgia'].
# Number of columns after merging = 3157
# Merging the following columns into one: ['title_colheita', 'designation_Colheita'].
# Number of columns after merging = 3156
# Merging the following columns into one: ['title_heritage', 'designation_Heritage'].
# Number of columns after merging = 3155
# Merging the following columns into one: ['title_auslese', 'designation_Auslese'].
# Number of columns after merging = 3154
# Merging the following columns into one: ['title_moscato', 'variety_Moscato'].
# Number of columns after merging = 3153
# Merging the following columns into one: ['title_siduri', 'winery_Siduri'].
# Number of columns after merging = 3152
# Merging the following columns into one: ['variety_Prosecco', 'region-1_Prosecco'].
# Number of columns after merging = 3151
# Merging the following columns into one: ['province_Germany', 'country_Germany'].
# Number of columns after merging = 3150
# Merging the following columns into one: ['province_Greece', 'country_Greece'].
# Number of columns after merging = 3149
# Merging the following columns into one: ['region-1_South Coast', 'region-2_South Coast'].
# Number of columns after merging = 3148
# Merging the following columns into one: ['region-1_Australia', 'country_Australia'].
# Number of columns after merging = 3147
# Merging the following columns into one: ['province_Uruguay', 'country_Uruguay'].
# Number of columns after merging = 3146
# Merging the following columns into one: ['title_monastrell', 'variety_Monastrell'].
# Number of columns after merging = 3145
# Merging the following columns into one: ['title_cabernet', 'variety_Cabernet'].
# Number of columns after merging = 3144
# Merging the following columns into one: ['title_sweet', 'designation_Sweet'].
# Number of columns after merging = 3143
# Merging the following columns into one: ['title_napa', 'region-2_Napa'].
# Number of columns after merging = 3142
# Merging the following columns into one: ['province_Romania', 'country_Romania'].
# Number of columns after merging = 3141
# Merging the following columns into one: ['title_torrontés', 'variety_Torrontés'].
# Number of columns after merging = 3140
# Merging the following columns into one: ['title_white', 'variety_White', 'variety_white', 'designation_White'].
# Number of columns after merging = 3137
# Merging the following columns into one: ['region-1_Michigan', 'province_Michigan'].
# Number of columns after merging = 3136
# Merging the following columns into one: ['title_grenache', 'variety_Grenache', 'designation_Grenache'].
# Number of columns after merging = 3134
# Merging the following columns into one: ['title_barbaresco', 'region-1_Barbaresco'].
# Number of columns after merging = 3133
# Merging the following columns into one: ['title_riserva', 'designation_Riserva'].
# Number of columns after merging = 3132
# Merging the following columns into one: ['title_ridge', 'winery_Ridge'].
# Number of columns after merging = 3131
# Merging the following columns into one: ['title_carmenère', 'variety_Carmenère'].
# Number of columns after merging = 3130
# Merging the following columns into one: ['region-1_California', 'province_California'].
# Number of columns after merging = 3129
# Merging the following columns into one: ['title_réserve', 'designation_Réserve'].
# Number of columns after merging = 3128
# Merging the following columns into one: ['title_bianco', 'variety_Bianco', 'designation_Bianco'].
# Number of columns after merging = 3126
# Merging the following columns into one: ['title_cuvée', 'designation_Cuvée'].
# Number of columns after merging = 3125
# Merging the following columns into one: ['title_selection', 'designation_Selection'].
# Number of columns after merging = 3124
# Merging the following columns into one: ['region-1_Idaho', 'province_Idaho'].
# Number of columns after merging = 3123
# Merging the following columns into one: ['variety_Champagne', 'region-1_Champagne', 'province_Champagne'].
# Number of columns after merging = 3121
# Merging the following columns into one: ['title_bordeaux', 'variety_Bordeaux', 'region-1_Bordeaux', 'province_Bordeaux'].
# Number of columns after merging = 3118
# Merging the following columns into one: ['title_pinotage', 'variety_Pinotage'].
# Number of columns after merging = 3117
# Merging the following columns into one: ['title_merlot', 'variety_Merlot'].
# Number of columns after merging = 3116
# Merging the following columns into one: ['title_meritage', 'variety_Meritage', 'designation_Meritage'].
# Number of columns after merging = 3114
# Merging the following columns into one: ['title_malbec', 'variety_Malbec'].
# Number of columns after merging = 3113
# Merging the following columns into one: ['province_Israel', 'country_Israel'].
# Number of columns after merging = 3112
# Merging the following columns into one: ['title_roussanne', 'variety_Roussanne'].
# Number of columns after merging = 3111
# Merging the following columns into one: ['region-1_New York', 'province_New York'].
# Number of columns after merging = 3110
# Merging the following columns into one: ['title_collection', 'designation_Collection'].
# Number of columns after merging = 3109
# Merging the following columns into one: ['title_primitivo', 'variety_Primitivo'].
# Number of columns after merging = 3108
# Merging the following columns into one: ['region-1_Arizona', 'province_Arizona'].
# Number of columns after merging = 3107
# Merging the following columns into one: ['region-1_Central Coast', 'region-2_Central Coast'].
# Number of columns after merging = 3106
# Merging the following columns into one: ['title_grigio', 'variety_Grigio'].
# Number of columns after merging = 3105
# Merging the following columns into one: ['region-1_South Australia', 'province_South Australia'].
# Number of columns after merging = 3104
# Merging the following columns into one: ['title_kabinett', 'designation_Kabinett'].
# Number of columns after merging = 3103
# Merging the following columns into one: ['title_dry', 'designation_Dry'].
# Number of columns after merging = 3102
# Merging the following columns into one: ['region-1_Sierra Foothills', 'region-2_Sierra Foothills'].
# Number of columns after merging = 3101
# Merging the following columns into one: ['title_shiraz', 'variety_Shiraz'].
# Number of columns after merging = 3100
# Merging the following columns into one: ['title_pinot', 'variety_Pinot'].
# Number of columns after merging = 3099
# Merging the following columns into one: ['region-1_Pennsylvania', 'province_Pennsylvania'].
# Number of columns after merging = 3098
# Merging the following columns into one: ['title_reserve', 'designation_Reserve'].
# Number of columns after merging = 3097
# Merging the following columns into one: ['region-1_Washington', 'province_Washington'].
# Number of columns after merging = 3096
# Merging the following columns into one: ['title_médoc', 'region-1_Médoc'].
# Number of columns after merging = 3095
# Merging the following columns into one: ['title_albariño', 'variety_Albariño'].
# Number of columns after merging = 3094
# Merging the following columns into one: ['title_blend', 'variety_Blend', 'variety_blend'].
# Number of columns after merging = 3092
# Merging the following columns into one: ['title_chardonnay', 'variety_Chardonnay'].
# Number of columns after merging = 3091
# Merging the following columns into one: ['title_foxen', 'winery_Foxen'].
# Number of columns after merging = 3090

# %%
with gzip.open('data/gzipX_train_transformed.pckl', 'wb') as f:
    pickle.dump(X_train_transformed, f)

with gzip.open('data/gzipX_holdout_transformed.pckl', 'wb') as f:
    pickle.dump(X_holdout_transformed, f)

with gzip.open('data/gzipX_val_transformed.pckl', 'wb') as f:
    pickle.dump(X_val_transformed, f)

with gzip.open('data/gzipy_train.pckl', 'wb') as f:
    pickle.dump(y_train, f)

with gzip.open('data/gzipy_val.pckl', 'wb') as f:
    pickle.dump(y_val, f)

with gzip.open('data/gzipy_holdout.pckl', 'wb') as f:
    pickle.dump(y_holdout, f)

# %%
import gzip

# %%
with gzip.open('data/X_train_transformed.pckl', 'wb') as f:
    pickle.dump(X_train_transformed, f)
