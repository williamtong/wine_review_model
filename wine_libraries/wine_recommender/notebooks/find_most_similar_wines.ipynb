# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

import numpy as np
import torch
import gzip
import os
import pickle

import importlib
import matplotlib.pyplot as plt

from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

from sentence_transformers import SentenceTransformer
# Out:
# /Users/willtong/Library/Caches/pypoetry/virtualenvs/wine-libraries-PLl6gzSz-py3.12/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
os.chdir('../../')
# importlib.reload(functions.similar_wines)
from functions.similar_wines import (find_your_wine, 
                                    info_features, 
                                    most_similar_wine_within_dataset, 
                                    stop_words, 
                                    find_your_wine_w_your_own_text
                                    )
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1000)>

# %%
pwd
# Out:
# '/Users/willtong/Documents/AI_models/wine_review_model/wine_libraries'

# %%
df = pd.read_json("data/deduped_mod_winemag-data-130k-v2.json")

# %%
model_name = 'msmarco-distilbert-dot-v5'
model_path = "data/embedded_desc_nostopwordsmsmarco-distilbert-dot-v5.pckl"
with gzip.open(model_path, "rb") as f:
    df_embeds = pickle.load(f)

# %%
text_transformer = SentenceTransformer(model_name)

# %%
your_wine_text = "I want a bubbly fruity refreshing sparkling wine" 
your_price = 20
price_importance = 0.01
find_your_wine_w_your_own_text(your_wine_text, 
                               your_price, 
                               df, 
                               df_embeds, 
                               text_transformer, 
                               price_importance = price_importance,
                               how_many_similar_wines = 6
                              )
# Out:
# Your desired wine: "I want a bubbly fruity refreshing sparkling wine", your desired price: $20
#                                                           title  \
# rank
# 1               The Winery SF NV Glitter Sparkling (California)
# 2               Wolfberger NV Brut Sparkling (Crémant d'Alsace)
# 3           River Road NV Brut Sparkling (Russian River Valley)
# 4     Mas de la Dame 2012 La Stèle White (Les Baux de Provence)
# 5                                Domaine de Rome 2015  Sancerre
# 6      Château Thuerry 2012 Le Château Rosé (Côtes de Provence)
#
#                                                                                                                                                                                                                      description  \
# rank
# ...

# %%
your_wine_text = 'robust red wine with hints of vanilla cinnamon coconut nutmeg'
your_price = 45
price_importance = 0.01
find_your_wine_w_your_own_text(your_wine_text, 
                               your_price, 
                               df, 
                               df_embeds, 
                               text_transformer, 
                               price_importance = price_importance,
                               how_many_similar_wines = 6
                              )
# Out:
# Your desired wine: "robust red wine with hints of vanilla cinnamon coconut nutmeg", your desired price: $45
#                                                              title  \
# rank
# 1                       La Crema 2013 Pinot Noir (Anderson Valley)
# 2            Clos Pegase 2012 Mitsuko's Vineyard Merlot (Carneros)
# 3         Bunnell 2009 Clifton Hill Vineyard Syrah (Wahluke Slope)
# 4                  Gehricke 2014 Pinot Noir (Russian River Valley)
# 5         Domaine Jessiaume 2008 Gravières Premier Cru  (Santenay)
# 6     :Nota Bene 2013 Ciel du Cheval Vineyard Syrah (Red Mountain)
#
#                                                                                                                                                                                                                                                                          description  \
# rank
# ...

# %%
your_wine_text = "a mature creamy chardonnay aged with oak" 
your_price = 35
price_importance = 0.01
find_your_wine_w_your_own_text(your_wine_text, 
                               your_price, 
                               df, 
                               df_embeds, 
                               text_transformer, 
                               price_importance = price_importance,
                               how_many_similar_wines = 6
                              )
# Out:
# Your desired wine: "a mature creamy chardonnay aged with oak", your desired price: $35
#                                                                                 title  \
# rank
# 1                                            Cloudy Bay 2006 Chardonnay (Marlborough)
# 2                                        Pride Mountain 2012 Chardonnay (Napa Valley)
# 3                        Millbrook 2013 Block 2 West Chardonnay (Hudson River Region)
# 4     McCall 2014 Reserve North Ridge Vineyard Chardonnay (North Fork of Long Island)
# 5                              Beringer 2008 Private Reserve Chardonnay (Napa Valley)
# 6                                    Y Rousseau 2012 Milady Chardonnay (Mount Veeder)
#
# ...

# %%
your_wine_text = 'A crisp dry sparkling wine, well balanced between orange and toast flavors.'
your_price = 60
price_importance = 0.01

find_your_wine_w_your_own_text(your_wine_text, 
                               your_price, 
                               df, 
                               df_embeds, 
                               text_transformer, 
                               price_importance = price_importance,
                               how_many_similar_wines = 6
                              )
# Out:
# Your desired wine: "A crisp dry sparkling wine, well balanced between orange and toast flavors.", your desired price: $60
#                                                                         title  \
# rank
# 1                           Piper-Heidsieck NV Sauvage Brut Rosé  (Champagne)
# 2                         Domaine Jacques Prieur 2008 Champs Pimont  (Beaune)
# 3                                     Jacquart NV Brut de Nominé  (Champagne)
# 4            Tendil & Lombardi NV Rosé de Saignée Brut Pinot Noir (Champagne)
# 5                       Joseph Perrier NV Cuvée Royale Brut Rosé  (Champagne)
# 6     J. M. Gobillard et Fils NV Grande Réserve Premier Cru Brut  (Champagne)
#
#                                                                                                                                                                                                                                           description  \
# rank
# ...

# %%
your_wine_text = 'fruity red wine with hints of vanilla”'
your_price = 25
price_importance = 0.01
find_your_wine_w_your_own_text(your_wine_text, 
                               your_price, 
                               df, 
                               df_embeds, 
                               text_transformer, 
                               price_importance = price_importance,
                               how_many_similar_wines = 6
                              )
# Out:
# Your desired wine: "fruity red wine with hints of vanilla”", your desired price: $25
#                                                                   title  \
# rank
# 1                                  Evening Land 2011 Blanc  (Bourgogne)
# 2                         Pardon et Fils 2011 Domaine Pardon  (Fleurie)
# 3                          Château Peyredon Lagravette 2011  Haut-Médoc
# 4                 Hazlitt 1852 Vineyards 2010 Pinot Noir (Finger Lakes)
# 5     Jérôme Gueneau 2016 Domaine des Grandes Perrières Rosé (Sancerre)
# 6                          Joseph Drouhin 2009  Côte de Beaune-Villages
#
#                                                                                                                                                                                                                                                                                                                                    description  \
# rank
# ...
